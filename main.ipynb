# %%
import speech_recognition as sr
import pyttsx3 

# Initialize the recognizer 
r = sr.Recognizer() 

# Function to convert text to
# speech
def SpeakText(command):
	
	# Initialize the engine
	engine = pyttsx3.init()
	engine.say(command) 
	engine.runAndWait()
	
	
# Loop infinitely for user to
# speak

while(1): 
	
	# Exception handling to handle
	# exceptions at the runtime
	try:
		
		# use the microphone as source for input.
		with sr.Microphone() as source2:
			
			# wait for a second to let the recognizer
			# adjust the energy threshold based on
			# the surrounding noise level 
			r.adjust_for_ambient_noise(source2, duration=0.2)
			
			#listens for the user's input 
			audio2 = r.listen(source2)
			
			
			# Using google to recognize audio
			MyText = r.recognize_google(audio2)
			MyText = MyText.lower()

			print("Did you say ",MyText)
			SpeakText(MyText)
			
	except sr.RequestError as e:
		print("Could not request results; {0}".format(e))
		
	except sr.UnknownValueError:
		print("unknown error occurred")
# Out:
# unknown error occurred
# unknown error occurred
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 35
#      32 r.adjust_for_ambient_noise(source2, duration=0.2)
#      34 #listens for the user's input
# ---> 35 audio2 = r.listen(source2)
#      37 # Using google to recognize audio
#      38 MyText = r.recognize_google(audio2)
#
# File d:\Software\anaconda3\Lib\site-packages\speech_recognition\__init__.py:523, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     520 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     521     break
# --> 523 buffer = source.stream.read(source.CHUNK)
#     524 if len(buffer) == 0: break  # reached end of the stream
#     525 frames.append(buffer)
#
# File d:\Software\anaconda3\Lib\site-packages\speech_recognition\__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File d:\Software\anaconda3\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:

# %%
from vosk import Model, KaldiRecognizer
import pyaudio

model = Model(r"D:\\Research\VAT\vosk-model-small-en-us-0.15")
recognizer = KaldiRecognizer(model, 16000)

mic = pyaudio.PyAudio()
stream = mic.open(format=pyaudio.paInt16, channels=1, rate=16000, input=True, frames_per_buffer=8192)
stream.start_stream()

while True:
    data = stream.read(4096)

    if recognizer.AcceptWaveform(data):
        text = recognizer.Result()
        print(f"' {text[14:-3]} '")
# Out:
# '  '
# '  '
# '  '
# ' hello '
# ' hi '
# ' one two three '
# '  '
# ' so '
# ' brace yourself for any children learn a journey to jane metro radio telescope '
# ' don't miss this opportunity to witness the marvels of his peers can embark on a journey that transcends that ordinary '
# ' yes '
# '  '
# ' manchin '
# ' him '
# ' satan '
# ' satan '
# '  '
# ' son '
# ' and done '
# ' mercury '
# ' venus '
# ' andromeda galaxy '
# '  '
# '  '
# ' trying to them galaxy '
# ' trying to learn galaxy '
# ' trained you love jealous '
# '  '
# '  '
# ' trying to do some kid '
# ' we do '
# ' what we do '
# '  '
# ' say something '
# ' say something '
# ' there's something '
# ' excluding the cost was lifted as is '
# ' no '
# ' it is living in a good year '
# ' it is a living in really well '
# ' god willing was really '
# ' the racing dish '
# ' supporting activities '
# ' teacher training workshops '
# ' recognizing the second '
# ' recognizing the bewildered don't have any interest '
# ' it is taking measured '
# ' noise this weekend for the some nice '
# ' perhaps '
# '  '
# ' we're getting a day '
# '  '
# ' yeah '
# ' the be within the instead '
# '  '
# ' you can and good good as be with this second windows billion to mention about but success is not good did every time and is despite cannot for made or years '
# ' so supporting activities better training workshops had a good muslim the pivotal role of into good this '
# '  '
# '  '
# '  '
# ' they put them behind it '
# ' it more than one need help keep the '
# ' what he's gonna get it '
# ' you in english for them '
# ' there's just testing we want you in english for the '
# ' a very effective remember michael '
# ' ha '
# ' make '
# ' little to address '
# ' blue book him a her ticket '
# ' then '
# ' the that '
# ' let me put discord on guitar '
# '  '
# '  '
# '  '
# '  '
# ' i'm good '
# '  '
# '  '
# '  '
# '  '
# ' what '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# ' huh '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# ' that '
# ' custom what '
# ' no depend on '
# ' consider beast is with a balloon operator '
# ' listen guys '
# ' i know but was made bail is a dataset mcgregor '
# ' therapy '
# ' definitely said and edinburgh was set on lives it as a the and '
# ' and i'm a dog a bigger than end of the mercury venus dead '
# ' the englander played out '
# ' great own galaxy '
# ' eight '
# '  '
# ' out and bought '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# '  '
# ' us '
# ' oh '
# '  '
